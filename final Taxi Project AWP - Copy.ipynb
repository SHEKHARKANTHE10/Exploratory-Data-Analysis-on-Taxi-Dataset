# %% [markdown]
# Project Taxis

# %%
#Matplotlib is a versatile and powerful library for creating a wide range of visualizations in Python.

# %%
#Seaborn is a Python data visualization library based on Matplotlib.
#It provides a high-level interface for drawing attractive and informative statistical graphics.

# %%
#NumPy (Numerical Python) is a fundamental library for scientific computing in Python.

# %%
#Pandas is a powerful and flexible open-source data analysis and manipulation library for Python.
#It is built on top of NumPy and provides data structures and functions needed to work on structured data seamlessly

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')
#The warnings.filterwarnings('ignore') function call is used to suppress all warnings. 
#This means that any warning that would normally be displayed will be ignored, and your script will run without printing those warning messages.

# %%
#this is used to get to knw the default dataset in system
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
taxis=sns.load_dataset('taxis')
taxis
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df=pd.DataFrame(taxis)

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB

# %%
df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6433                           6433
# mean   2019-03-16 08:31:28.514223616  2019-03-16 08:45:49.491217408
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:50:34            2019-03-08 16:12:51
# 50%              2019-03-15 21:46:58            2019-03-15 22:06:44
# 75%              2019-03-23 17:41:38            2019-03-23 17:51:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare         tip        tolls  \
# count  6433.000000  6433.000000  6433.000000  6433.00000  6433.000000
# mean      1.539251     3.024617    13.091073     1.97922     0.325273
# min       0.000000     0.000000     1.000000     0.00000     0.000000
# 25%       1.000000     0.980000     6.500000     0.00000     0.000000
# ...

# %%
df.shape
# Out:
# (6433, 14)

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
df.dtypes
# Out:
# pickup             datetime64[ns]
# dropoff            datetime64[ns]
# passengers                  int64
# distance                  float64
# fare                      float64
# tip                       float64
# tolls                     float64
# total                     float64
# color                      object
# payment                    object
# pickup_zone                object
# dropoff_zone               object
# pickup_borough             object
# dropoff_borough            object
# dtype: object

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
df.tail()
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total  color      payment          pickup_zone  \
# 6428  1.06    0.0   6.36  green  credit card    East Harlem North
# 6429  0.00    0.0  58.80  green  credit card              Jamaica
# 6430  0.00    0.0  17.30  green         cash  Crown Heights North
# 6431  0.00    0.0   6.80  green  credit card        East New York
# 6432  3.36    0.0  20.16  green  credit card          Boerum Hill
#
#                           dropoff_zone pickup_borough dropoff_borough
# ...

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df_temp=df

# %%
df_temp
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df_temp=df_temp.drop(columns='total')

# %%
df_temp
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls   color      payment            pickup_zone  \
# ...

# %%
df_temp.insert(7,'total', df_temp['fare'] + df_temp['tip'] + df_temp['tolls'])

# %%
df_temp
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df_temp.isnull().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
null_sum1=(df_temp.isnull().sum()/df_temp.shape[0])*100

# %%
null_sum1
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.683973
# pickup_zone        0.404166
# dropoff_zone       0.699518
# pickup_borough     0.404166
# dropoff_borough    0.699518
# dtype: float64

# %%
df_temp.isnull().sum().sum() #it gives total cell having null values
# Out:
# 186

# %%
(df_temp.isnull().sum().sum()/(df_temp.shape[0]*df_temp.shape[1]))*100  #percentage of cells which are having null values
# Out:
# 0.20652439430614467

# %%
df_temp
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df_new=df_temp

# %%
df_new

# %%
df_temp
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df_temp.dropna(inplace=True)
#This method removes rows (or columns) that contain missing values (NaN).
#inplace=True modifies the original DataFrame directly, rather than returning a new DataFrame with the missing values dropped.
#By default, dropna() removes rows with any missing values. You can also specify axis=1 to remove columns instead.

# %%
df_temp
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df_new.shape
# Out:
# (6341, 14)

# %%
df_temp.shape #value changed from (6433,14) to this one. Cleaning is done
# Out:
# (6341, 14)

# %%
df_temp.isnull().sum()
# Out:
# pickup             0
# dropoff            0
# passengers         0
# distance           0
# fare               0
# tip                0
# tolls              0
# total              0
# color              0
# payment            0
# pickup_zone        0
# dropoff_zone       0
# pickup_borough     0
# dropoff_borough    0
# dtype: int64

# %%
df_temp['payment'].value_counts()
#this indicates that people used credit card more than cash
# Out:
# payment
# credit card    4546
# cash           1795
# Name: count, dtype: int64

# %%
df_temp['tolls'].value_counts()
#some routes had tolls and majority of the routes had no tolls
# Out:
# tolls
# 0.00     6003
# 5.76      316
# 2.64        6
# 11.52       4
# 5.54        2
# 6.12        2
# 8.40        1
# 17.28       1
# 12.50       1
# 9.50        1
# 5.75        1
# 24.02       1
# 8.50        1
# 4.75        1
# Name: count, dtype: int64

# %%
df_new['distance'].unique()
# Out:
# array([ 1.6 ,  0.79,  1.37, ...,  9.12,  7.07, 18.74])

# %%
df_new['distance'].value_counts()
#the value counts gives us the insights that maximum distance travelled by passengers is more between 1 and 2 KM
# Out:
# distance
# 0.80     130
# 1.00     117
# 0.90     113
# 1.10     106
# 0.70     106
#         ...
# 4.92       1
# 6.68       1
# 12.27      1
# 7.43       1
# 18.74      1
# Name: count, Length: 1064, dtype: int64

# %%
df_new['color'].unique()
# Out:
# array(['yellow', 'green'], dtype=object)

# %%
df_new['color'].value_counts()
#there are 5 times more yellow coloured taxis as compared to green coloured taxis
#this means yellow coloured taxis are most used and prefered taxis  
#light green cabs  are only allowed to pick up fares in the outer boroughs(town or district) and northern Manhattan
#Yellow Taxis pick up street-hailing passengers anywhere in NYC.
# Out:
# color
# yellow    5373
# green      968
# Name: count, dtype: int64

# %%
df_new['passengers'].value_counts()
#this indicate that while travelling for single trip most passenger count is 1 and so on.
#so this also helps us to realize that if a person is willing to become a taxi driver then he should prefer to purchase a 4 seater vehicle which will have less amount or budget
#The dropoff location couldn’t be tracked.
#The driver deliberately took this ride to complete a target ride number.
#The passengers canceled the trip.
# Out:
# passengers
# 1    4608
# 2     865
# 5     277
# 3     240
# 6     152
# 4     109
# 0      90
# Name: count, dtype: int64

# %%
df_new['pickup_zone'].value_counts()
#this indicates the most and least prefered pickup zones 
#the taxis are highly used in these regions 
#Also the taxi drivers will prefer to stay in these region for travelling
# Out:
# pickup_zone
# Midtown Center                  227
# Penn Station/Madison Sq West    209
# Upper East Side South           208
# Clinton East                    208
# Midtown East                    196
#                                ...
# Highbridge Park                   1
# Brighton Beach                    1
# Bronx Park                        1
# Crotona Park East                 1
# Hillcrest/Pomonok                 1
# Name: count, Length: 194, dtype: int64

# %%
df_new['pickup_zone'].unique()
# Out:
# array(['Lenox Hill West', 'Upper West Side South', 'Alphabet City',
#        'Hudson Sq', 'Midtown East', 'Times Sq/Theatre District',
#        'Battery Park City', 'East Harlem South', 'Lincoln Square East',
#        'LaGuardia Airport', 'Murray Hill', 'Lincoln Square West',
#        'Financial District North', 'Upper West Side North',
#        'East Chelsea', 'Midtown Center', 'Gramercy',
#        'Penn Station/Madison Sq West', 'Sutton Place/Turtle Bay North',
#        'West Chelsea/Hudson Yards', 'Clinton East', 'Clinton West',
#        'UN/Turtle Bay South', 'Midtown South', 'Midtown North',
#        'Garment District', 'Lenox Hill East', 'Flatiron',
#        'TriBeCa/Civic Center', 'Upper East Side North', 'West Village',
#        'Greenwich Village South', 'JFK Airport', 'East Village',
#        'Union Sq', 'Yorkville West', 'Central Park',
#        'Meatpacking/West Village West', 'Kips Bay', 'Morningside Heights',
#        'Astoria', 'East Tremont', 'Upper East Side South',
# ...

# %%
df['dropoff_zone'].value_counts()
# Out:
# dropoff_zone
# Upper East Side North        245
# Murray Hill                  220
# Midtown Center               215
# Upper East Side South        177
# Midtown East                 176
#                             ...
# Bensonhurst East               1
# Springfield Gardens South      1
# East Flushing                  1
# Brighton Beach                 1
# Ozone Park                     1
# Name: count, Length: 203, dtype: int64

# %%
sns.countplot(x='payment',data=df_temp)
#passenger preferred to pay bill with credit card more as compared to cash
# Out:
# <Axes: xlabel='payment', ylabel='count'>

# %%
sns.countplot(data=df_temp,x='payment',hue='color')
# Out:
# <Axes: xlabel='payment', ylabel='count'>

# %%
plt.hist(df_temp['tip'],color='yellow',edgecolor='black')
plt.title('Tips given to taxi')
plt.xlabel('Tips')
plt.ylabel('Count')
plt.show()
#A histogram is a graphical representation of the distribution of numerical data.
#tips given is highest in the range of 0 to 4$ and its count is more than 5000

# %%
sns.countplot(x='passengers',data=df_temp)
plt.title('No of Passengers')
plt.xlabel('Passenger')
plt.ylabel('Count')
plt.show()

# %%
'''
Insights and Summary
1)the value counts gives us the insights that maximum distance travelled by passengers is more between 1 and 2 KM
2)there are 5 times more yellow coloured taxis as compared to green coloured taxis
3)this means yellow coloured taxis are most used and prefered taxis  
4)light green cabs were added, but they are only allowed to pick up fares in the outer boroughs(town or district) and northern Manhattan
5)Yellow Taxis pick up street-hailing passengers anywhere in NYC.
6)while travelling for single trip most passenger count is 1 and so on.
7)so this also helps us to realize that if a person is willing to become a taxi driver then he should prefer to purchase a 4 seater vehicle as compared to 6 seater car
 which will have less amount or budget
8)Passenger count has a minimum of 0 value which means a) drivers deliberately took the ride to complete a target number of rides
                                                       b)The dropoff location couldn’t be tracked.
                                                       c) The passengers canceled the trip.
11)Credit card is used more than cash for paying the bills
12)Majority of routes had no tolls but some had tolls
13)the EDA also  helped us to understand the high demand area and low demand areas for taxis

'''
